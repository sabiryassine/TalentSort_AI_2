# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (5.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from plotly) (8.1.0)
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pdfminer3
# Out:
# Requirement already satisfied: pdfminer3 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (2018.12.3.0)
# Requirement already satisfied: pycryptodome in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pdfminer3) (3.20.0)
# Requirement already satisfied: sortedcontainers in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pdfminer3) (2.4.0)
# Requirement already satisfied: chardet in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pdfminer3) (5.2.0)
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install streamlit-tags
# Out:
# Requirement already satisfied: streamlit-tags in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (1.2.8)
# Requirement already satisfied: streamlit>=0.63 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from streamlit-tags) (1.11.1)
# Requirement already satisfied: altair>=3.2.0 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from streamlit>=0.63->streamlit-tags) (4.2.0)
# Requirement already satisfied: attrs>=16.0.0 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from streamlit>=0.63->streamlit-tags) (22.1.0)
# Requirement already satisfied: blinker>=1.0.0 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from streamlit>=0.63->streamlit-tags) (1.5)
# Requirement already satisfied: cachetools>=4.0 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from streamlit>=0.63->streamlit-tags) (5.2.0)
# Requirement already satisfied: click>=7.0 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from streamlit>=0.63->streamlit-tags) (8.1.3)
# Requirement already satisfied: gitpython!=3.1.19 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from streamlit>=0.63->streamlit-tags) (3.1.29)
# Requirement already satisfied: importlib-metadata>=1.4 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from streamlit>=0.63->streamlit-tags) (5.0.0)
# Requirement already satisfied: numpy in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from streamlit>=0.63->streamlit-tags) (1.23.4)
# Requirement already satisfied: packaging>=14.1 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from streamlit>=0.63->streamlit-tags) (21.3)
# Requirement already satisfied: pandas>=0.21.0 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from streamlit>=0.63->streamlit-tags) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from streamlit>=0.63->streamlit-tags) (9.1.1)
# Requirement already satisfied: protobuf<4,>=3.12 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from streamlit>=0.63->streamlit-tags) (3.19.6)
# Requirement already satisfied: pyarrow>=4.0 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from streamlit>=0.63->streamlit-tags) (8.0.0)
# Requirement already satisfied: pydeck>=0.1.dev5 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from streamlit>=0.63->streamlit-tags) (0.8.0b4)
# Requirement already satisfied: pympler>=0.9 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from streamlit>=0.63->streamlit-tags) (1.0.1)
# Requirement already satisfied: python-dateutil in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from streamlit>=0.63->streamlit-tags) (2.8.2)
# Requirement already satisfied: requests>=2.4 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from streamlit>=0.63->streamlit-tags) (2.28.1)
# Requirement already satisfied: rich>=10.11.0 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from streamlit>=0.63->streamlit-tags) (12.6.0)
# Requirement already satisfied: semver in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from streamlit>=0.63->streamlit-tags) (2.13.0)
# Requirement already satisfied: toml in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from streamlit>=0.63->streamlit-tags) (0.10.2)
# Requirement already satisfied: tornado>=5.0 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from streamlit>=0.63->streamlit-tags) (6.2)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from streamlit>=0.63->streamlit-tags) (4.4.0)
# Requirement already satisfied: tzlocal>=1.1 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from streamlit>=0.63->streamlit-tags) (4.2)
# Requirement already satisfied: validators>=0.2 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from streamlit>=0.63->streamlit-tags) (0.20.0)
# Requirement already satisfied: watchdog in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from streamlit>=0.63->streamlit-tags) (2.1.9)
# Requirement already satisfied: entrypoints in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from altair>=3.2.0->streamlit>=0.63->streamlit-tags) (0.4)
# Requirement already satisfied: jinja2 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from altair>=3.2.0->streamlit>=0.63->streamlit-tags) (3.1.2)
# Requirement already satisfied: jsonschema>=3.0 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from altair>=3.2.0->streamlit>=0.63->streamlit-tags) (4.16.0)
# Requirement already satisfied: toolz in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from altair>=3.2.0->streamlit>=0.63->streamlit-tags) (0.12.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from gitpython!=3.1.19->streamlit>=0.63->streamlit-tags) (4.0.9)
# Requirement already satisfied: zipp>=0.5 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from importlib-metadata>=1.4->streamlit>=0.63->streamlit-tags) (3.10.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from packaging>=14.1->streamlit>=0.63->streamlit-tags) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pandas>=0.21.0->streamlit>=0.63->streamlit-tags) (2022.1)
# Requirement already satisfied: six>=1.5 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from python-dateutil->streamlit>=0.63->streamlit-tags) (1.16.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests>=2.4->streamlit>=0.63->streamlit-tags) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests>=2.4->streamlit>=0.63->streamlit-tags) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests>=2.4->streamlit>=0.63->streamlit-tags) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from requests>=2.4->streamlit>=0.63->streamlit-tags) (2022.9.24)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from rich>=10.11.0->streamlit>=0.63->streamlit-tags) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from rich>=10.11.0->streamlit>=0.63->streamlit-tags) (2.13.0)
# Requirement already satisfied: pytz-deprecation-shim in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from tzlocal>=1.1->streamlit>=0.63->streamlit-tags) (0.1.0.post0)
# Requirement already satisfied: decorator>=3.4.0 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from validators>=0.2->streamlit>=0.63->streamlit-tags) (5.1.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit>=0.63->streamlit-tags) (5.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jinja2->altair>=3.2.0->streamlit>=0.63->streamlit-tags) (2.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit>=0.63->streamlit-tags) (0.18.1)
# Requirement already satisfied: tzdata in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (from pytz-deprecation-shim->tzlocal>=1.1->streamlit>=0.63->streamlit-tags) (2022.5)
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymysql
# Out:
# Requirement already satisfied: pymysql in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (1.1.0)
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pafy
# Out:
# Requirement already satisfied: pafy in /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages (0.5.5)
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install youtube-dl
# Out:
# Collecting youtube-dl
#   Using cached youtube_dl-2021.12.17-py2.py3-none-any.whl.metadata (1.5 kB)
# Using cached youtube_dl-2021.12.17-py2.py3-none-any.whl (1.9 MB)
# Installing collected packages: youtube-dl
# Successfully installed youtube-dl-2021.12.17
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python3.10 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
import nltk
import spacy
nltk.download('stopwords')
spacy.load('en_core_web_sm')

import pandas as pd
import base64, random
import time, datetime
from pyresparser import ResumeParser
from pdfminer3.layout import LAParams, LTTextBox
from pdfminer3.pdfpage import PDFPage
from pdfminer3.pdfinterp import PDFResourceManager
from pdfminer3.pdfinterp import PDFPageInterpreter
from pdfminer3.converter import TextConverter
import io, random
from streamlit_tags import st_tags
import pymysql
from Courses import ds_course, web_course, android_course, ios_course, uiux_course, resume_videos, interview_videos
import pafy
import plotly.express as px
import json



def get_table_download_link(df, filename, text):
    """Generates a link allowing the data in a given panda dataframe to be downloaded
    in:  dataframe
    out: href string
    """
    csv = df.to_csv(index=False)
    b64 = base64.b64encode(csv.encode()).decode()  
    href = f'<a href="data:file/csv;base64,{b64}" download="{filename}">{text}</a>'
    return href


def pdf_reader(file):
    resource_manager = PDFResourceManager()
    fake_file_handle = io.StringIO()
    converter = TextConverter(resource_manager, fake_file_handle, laparams=LAParams())
    page_interpreter = PDFPageInterpreter(resource_manager, converter)
    with open(file, 'rb') as fh:
        for page in PDFPage.get_pages(fh,
                                      caching=True,
                                      check_extractable=True):
            page_interpreter.process_page(page)
            print(page)
        text = fake_file_handle.getvalue()

    # close open handles
    converter.close()
    fake_file_handle.close()
    return text


def show_pdf(file_path):
    with open(file_path, "rb") as f:
        base64_pdf = base64.b64encode(f.read()).decode('utf-8')
    pdf_display = F'<iframe src="data:application/pdf;base64,{base64_pdf}" width="700" height="1000" type="application/pdf"></iframe>'
    st.markdown(pdf_display, unsafe_allow_html=True)


connection = pymysql.connect(host='localhost', user='root', password='')
cursor = connection.cursor()
    

def insert_data(name, email, no_of_pages , skills, college_name, degree, designation, res_score):
    DB_table_name = 'users_data'
    insert_sql = f"INSERT INTO {DB_table_name} VALUES (0, %s, %s, %s, %s, %s, %s, %s, %s)"
    rec_values = (name, email, str(no_of_pages), skills, college_name, degree, designation, str(res_score))
    cursor.execute(insert_sql, rec_values)
    connection.commit()

st.set_page_config(
    page_title="Resume Parser",
    #page_icon='./Logo/mypyli.ico',
)



def run():
    st.title("Smart Resume Parser")
    st.sidebar.markdown("# Choose User")
    activities = ["Normal User", "Admin"]
    choice = st.sidebar.selectbox("Choose among the given options:", activities)

    # Create the DB
    db_sql = """CREATE DATABASE IF NOT EXISTS SRA;"""
    cursor.execute(db_sql)
    connection.select_db("sra")

    # Create table
    DB_table_name = 'users_data'
    table_sql = "CREATE TABLE IF NOT EXISTS " + DB_table_name + """
                    (ID INT NOT NULL AUTO_INCREMENT,
                     Name VARCHAR(100) NOT NULL,
                     Email VARCHAR(50) NOT NULL,
                     Page_no VARCHAR(5) NOT NULL,
                     College_name VARCHAR(50) NOT NULL,
                     Actual_skills VARCHAR(300) NOT NULL,
                     Degree VARCHAR(100) NOT NULL,
                     Designation VARCHAR(300) NOT NULL,
                     Resume_score VARCHAR(8) NOT NULL,
                     PRIMARY KEY (ID));
                    """
    cursor.execute(table_sql)
    if choice == 'Normal User':
        pdf_file = st.file_uploader("Choose your Resume", type=["pdf"])
        if pdf_file is not None:
            save_image_path = './Uploaded_Resumes/' + pdf_file.name
            with open(save_image_path, "wb") as f:
                f.write(pdf_file.getbuffer())
            show_pdf(save_image_path)
            resume_data = ResumeParser(save_image_path).get_extracted_data()
            if resume_data:
                ## Get the whole resume data
                resume_text = pdf_reader(save_image_path)

                st.header("**Resume Analysis**")
                st.success("Hello " + resume_data['name'])
                st.subheader("**Your Basic info**")
                
                st.json(resume_data)

                # Download button for JSON
                st.download_button(
                    label="Download JSON",
                    data=json.dumps(resume_data, indent=2),
                    file_name="resume_data.json",
                    key="download-json-btn"
                )                              
        

                ### Resume writing recommendation
                st.subheader("**Resume Tips & Ideas💡**")
                resume_score = 0
                if 'Objective' in resume_text:
                    resume_score = resume_score + 20
                    st.markdown(
                        '''<h4 style='text-align: left; color: #1ed760;'>[+] Awesome! You have added Objective</h4>''',
                        unsafe_allow_html=True)
                else:
                    st.markdown(
                        '''<h4 style='text-align: left; color: #fabc10;'>[-] According to our recommendation please add your career objective, it will give your career intension to the Recruiters.</h4>''',
                        unsafe_allow_html=True)

                if 'Declaration' in resume_text:
                    resume_score = resume_score + 20
                    st.markdown(
                        '''<h4 style='text-align: left; color: #1ed760;'>[+] Awesome! You have added Delcaration✍/h4>''',
                        unsafe_allow_html=True)
                else:
                    st.markdown(
                        '''<h4 style='text-align: left; color: #fabc10;'>[-] According to our recommendation please add Declaration✍. It will give the assurance that everything written on your resume is true and fully acknowledged by you</h4>''',
                        unsafe_allow_html=True)

                if 'Hobbies' or 'Interests' in resume_text:
                    resume_score = resume_score + 20
                    st.markdown(
                        '''<h4 style='text-align: left; color: #1ed760;'>[+] Awesome! You have added your Hobbies⚽</h4>''',
                        unsafe_allow_html=True)
                else:
                    st.markdown(
                        '''<h4 style='text-align: left; color: #fabc10;'>[-] According to our recommendation please add Hobbies⚽. It will show your persnality to the Recruiters and give the assurance that you are fit for this role or not.</h4>''',
                        unsafe_allow_html=True)

                if 'Achievements' in resume_text:
                    resume_score = resume_score + 20
                    st.markdown(
                        '''<h4 style='text-align: left; color: #1ed760;'>[+] Awesome! You have added your Achievements🏅 </h4>''',
                        unsafe_allow_html=True)
                else:
                    st.markdown(
                        '''<h4 style='text-align: left; color: #fabc10;'>[-] According to our recommendation please add Achievements🏅. It will show that you are capable for the required position.</h4>''',
                        unsafe_allow_html=True)

                if 'Projects' in resume_text:
                    resume_score = resume_score + 20
                    st.markdown(
                        '''<h4 style='text-align: left; color: #1ed760;'>[+] Awesome! You have added your Projects👨‍💻 </h4>''',
                        unsafe_allow_html=True)
                else:
                    st.markdown(
                        '''<h4 style='text-align: left; color: #fabc10;'>[-] According to our recommendation please add Projects👨‍💻. It will show that you have done work related the required position or not.</h4>''',
                        unsafe_allow_html=True)

                st.subheader("**Resume Score📝**")
                st.markdown(
                    """
                    <style>
                        .stProgress > div > div > div > div {
                            background-color: #d73b5c;
                        }
                    </style>""",
                    unsafe_allow_html=True,
                )
                my_bar = st.progress(0)
                score = 0
                for percent_complete in range(resume_score):
                    score += 1
                    time.sleep(0.1)
                    my_bar.progress(percent_complete + 1)
                st.success('** Your Resume Writing Score: ' + str(score) + '**')
                st.warning(
                    "** Note: This score is calculated based on the content that you have added in your Resume. **")
                st.balloons()

                insert_data(resume_data['name'],
                            resume_data['email'],
                            str(resume_data['no_of_pages']),
                            str(resume_data['skills']),
                            str(resume_data['college_name']),
                            str(resume_data['degree']),
                            str(resume_data['designation']),
                            str(resume_score)
                           )

                connection.commit()
            else:
                st.error('Something went wrong..')
                
                
                
                
    else:
        ## Admin Side
        st.success('Welcome to Admin Page')
        # st.sidebar.subheader('**ID / Password Required!**')

        ad_user = st.text_input("Username")
        ad_password = st.text_input("123", type='password')
        if st.button('Login'):
            if ad_user == 'machine_learning_hub' and ad_password == 'ml123':
                st.success("Welcome Admin")
                # Display Data
                cursor.execute('''SELECT*FROM users_data''')
             

            else:
                st.error("Wrong ID & Password Provided")


run()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/sabiryassine/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-03-07 09:17:25.062
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /home/sabiryassine/.pyenv/versions/3.10.6/envs/lewagon/lib/python3.10/site-packages/ipykernel_launcher.py [ARGUMENTS]
